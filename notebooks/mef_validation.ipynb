# %%
import pandas as pd

# %%
amprion = pd.read_csv('../results/amprion_run_1_2024/tables/df_mef_final.csv')

# %%
amprion.columns
# Out:
# Index(['datetime', 'total_generation', 'total_emissions', 'mef_t_MWh',
#        'mef_g_kWh', 'intercept'],
#       dtype='object')

# %%
amprion['mef_g_kWh']
# Out:
# 0        771.901511
# 1        899.402003
# 2        897.287266
# 3        899.603712
# 4        416.008916
#             ...
# 35232    584.193193
# 35233    595.701005
# 35234    563.319654
# 35235    521.405821
# 35236    417.448547
# Name: mef_g_kWh, Length: 35237, dtype: float64

# %%
87/35237
# Out:
# 0.0024689956579731533
