# %%
import requests
from pprint import pprint

response = requests.get(
    "https://api.electricitymaps.com/v3/carbon-intensity-fossil-only/past-range?zone=DE&start=2022-12-24T00%3A00%3A00.000Z&end=2022-12-26T23%3A45%3A00.000Z&temporalGranularity=15_minutes&emissionFactorType=direct",
    headers={
        "auth-token": f"g1CjEZxUkNJSE8MajDhN"
    }
)
pprint(response.json())
# Out:
# {'data': [{'createdAt': '2025-07-01T01:46:08.706Z',
#            'datetime': '2022-12-24T00:00:00.000Z',
#            'emissionFactorType': 'lifecycle',
#            'estimationMethod': None,
#            'isEstimated': False,
#            'updatedAt': '2026-02-04T23:58:15.642Z',
#            'value': 1046.18},
#           {'createdAt': '2025-07-01T00:45:42.682Z',
#            'datetime': '2022-12-24T00:15:00.000Z',
#            'emissionFactorType': 'lifecycle',
#            'estimationMethod': None,
#            'isEstimated': False,
#            'updatedAt': '2026-02-04T23:58:15.519Z',
#            'value': 1039.92},
#           {'createdAt': '2025-07-01T00:45:33.492Z',
#            'datetime': '2022-12-24T00:30:00.000Z',
#            'emissionFactorType': 'lifecycle',
#            'estimationMethod': None,
#            'isEstimated': False,
#            'updatedAt': '2026-02-04T23:58:15.642Z',
#            'value': 1035.15},
#           {'createdAt': '2025-07-01T00:45:33.492Z',
# ...
