# %%
import pandas as pd
import logging

from marginal_emissions.utils.helper import check_encoding
logging.basicConfig(level=logging.INFO, format='[%(levelname)s][%(asctime)s][%(filename)s]_%(message)s')

# %%
kws_path = '../data/raw/bundesnetzagentur/kraftwerksliste.csv'
cdc_path = '../data/raw/bundesnetzagentur/ZuUndRueckbau.xlsx' # cdc = commission/decommission

# %%
kws_encoding = check_encoding(path=kws_path)

if kws_encoding:
    kws = pd.read_csv(kws_path, sep=';', skiprows=11, header=0, encoding=kws_encoding, usecols=[
        'Anzeige-Name der Stromerzeugungseinheit',
        'Bundesland der Einheit',
        'Ort der Einheit',
        'Kraftwerksstatus der Einheit',
        'Energieträger',
        'Speichertechnologie',
        'Nettonennleistung (elektrische Wirkleistung) in MW',
        'Technologie der Stromerzeugung',
        'Spannungsebene'
    ]).rename(columns={
        'Anzeige-Name der Stromerzeugungseinheit': 'Name',
        'Bundesland der Einheit': 'Bundesland',
        'Ort der Einheit': 'Ort',
        'Kraftwerksstatus der Einheit': 'Status',
        'Nettonennleistung (elektrische Wirkleistung) in MW': 'Net_Wirkleistung',
        'Technologie der Stromerzeugung': 'Technologie'
    })

    kw_name = kws[kws['Name'].str.contains('Wendefurth', case=False, na=False)]
    kw_carrier = kws[kws['Energieträger'].str.contains('Speicher', case=False, na=False)]
    kw_carrier_pump = kw_carrier[kw_carrier['Speichertechnologie'] == 'Pumpspeicher']
    print("# Kraftwerke: ", len(kws))
    print("# Speicher: ", len(kw_carrier_pump))

# %%
kw_carrier_pump
# Out:
#                    Name            Ort          Bundesland      Status  \
# 57      KW Säckingen A7  Bad Säckingen   Baden-Württemberg  In Betrieb
# 58      KW Säckingen A8  Bad Säckingen   Baden-Württemberg  In Betrieb
# 59      KW Säckingen B7  Bad Säckingen   Baden-Württemberg  In Betrieb
# 60      KW Säckingen B8  Bad Säckingen   Baden-Württemberg  In Betrieb
# 349   Bringhausen M3 F1        Edertal              Hessen  In Betrieb
# ...                 ...            ...                 ...         ...
# 2103                NaN            NaN            Saarland  In Betrieb
# 2104                NaN            NaN             Sachsen  In Betrieb
# 2105                NaN            NaN      Sachsen-Anhalt  In Betrieb
# 2106                NaN            NaN  Schleswig-Holstein  In Betrieb
# 2107                NaN            NaN           Thüringen  In Betrieb
#
#      Energieträger Speichertechnologie Net_Wirkleistung Technologie  \
# 57        Speicher        Pumpspeicher            90,00         NaN
# 58        Speicher        Pumpspeicher            90,00         NaN
# 59        Speicher        Pumpspeicher            90,00         NaN
# 60        Speicher        Pumpspeicher            90,00         NaN
# 349       Speicher        Pumpspeicher            35,00         NaN
# ...            ...                 ...              ...         ...
# 2103      Speicher        Pumpspeicher             0,00         NaN
# 2104      Speicher        Pumpspeicher             0,00         NaN
# 2105      Speicher        Pumpspeicher             0,00         NaN
# 2106      Speicher        Pumpspeicher             0,00         NaN
# 2107      Speicher        Pumpspeicher             0,00         NaN
#
#                       Spannungsebene
# 57    Höchstspannung; Höchstspannung
# 58    Höchstspannung; Höchstspannung
# 59                    Höchstspannung
# 60                    Höchstspannung
# 349                     Hochspannung
# ...                              ...
# 2103                             NaN
# 2104                             NaN
# 2105                             NaN
# 2106                             NaN
# 2107                             NaN
#
# [114 rows x 9 columns]
