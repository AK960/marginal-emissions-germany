# %%
import pandas as pd
import logging
from marginal_emissions.utils.helper import search_df, check_encoding
logging.basicConfig(level=logging.INFO, format='[%(levelname)s][%(asctime)s][%(filename)s]_%(message)s')

# %%
kws_path = '../data/raw/bundesnetzagentur/kraftwerksliste.csv'
cdc_path = '../data/raw/bundesnetzagentur/ZuUndRueckbau.xlsx' # cdc = commission/decommission
wind_path = '~/Downloads/stundenwerte_FF_00282_19710801_20241231_hist/produkt_ff_stunde_19710801_20241231_00282.txt' # avgeraged by hour
wind_path2 = '~/Downloads/stundenwerte_F_00282_19490101_20241231_hist/produkt_f_stunde_19490101_20241231_00282.txt' # hourly values
ele_em = '../data/raw/electricitymaps/DE_2024_hourly.csv'

# %%
kws_encoding = check_encoding(path=kws_path)

# To check exact column names
kws_cols = pd.read_csv(kws_path, sep=';', skiprows=11, header=0, nrows=5, encoding='Windows-1252')

if kws_encoding:
    kws = pd.read_csv(kws_path, sep=';', skiprows=11, header=0, encoding=kws_encoding, usecols=[
        'Anzeige-Name der Stromerzeugungseinheit',
        'Anlagenbetreiber',
        'Anschlussnetzbetreiber',
        'Bundesland der Einheit',
        'Ort der Einheit',
        'Kraftwerksstatus der Einheit',
        'Energieträger',
        'Speichertechnologie',
        'Wärmeauskopplung (KWK)\n(ja/nein)',
        'Nettonennleistung (elektrische Wirkleistung) in MW',
        'Technologie der Stromerzeugung',
        'Spannungsebene'
    ]).rename(columns={
        'Anzeige-Name der Stromerzeugungseinheit': 'Name',
        'Bundesland der Einheit': 'Bundesland',
        'Ort der Einheit': 'Ort',
        'Kraftwerksstatus der Einheit': 'Status',
        'Wärmeauskopplung (KWK)\n(ja/nein)': 'KWK',
        'Nettonennleistung (elektrische Wirkleistung) in MW': 'Net_Wirkleistung',
        'Technologie der Stromerzeugung': 'Technologie'
    })

    kw_carrier = kws[kws['Energieträger'].str.contains('Speicher', case=False, na=False)].drop(columns='Technologie')
    kw_carrier_pump = kw_carrier[kw_carrier['Speichertechnologie'] == 'Pumpspeicher']
    kw_solar = search_df(kws, 'Solar').copy() # use .copy() to avoid modifying
    kw_solar.Net_Wirkleistung = kw_solar.Net_Wirkleistung.str.replace('.', '', regex=False).str.replace(',', '.', regex=False).astype(float) # makes float from string
    kw_wind = kws[kws['Energieträger'].str.contains('wind', case=False, na=False)].copy()
    kw_wind.Net_Wirkleistung = kw_wind.Net_Wirkleistung.str.replace('.', '', regex=False).str.replace(',', '.', regex=False).astype(float) # makes float from string
    kw_kwk = kws[kws['KWK'] == 'Ja']

    print("# Kraftwerke: ", len(kws))
    print("# Speicher: ", len(kw_carrier_pump))
    print("# Must-Run: ", len(kw_kwk))

    # Einzeiler für eine ganze Spalte
    # df['column_name'] = df['column_name'].str.replace('.', '', regex=False).str.replace(',', '.').astype(float)
# Out:
# [INFO][2026-01-08 13:49:20][helper.py] Checking encoding of file "../data/raw/bundesnetzagentur/kraftwerksliste.csv"...
# [INFO][2026-01-08 13:49:20][helper.py] File is encoded as "Windows-1252"
# [INFO][2026-01-08 13:49:20][helper.py] Found 22 rows matching 'Solar' pattern.
# # Kraftwerke:  2220
# # Speicher:  114
# # Must-Run:  1158

# %%
kws['Anschlussnetzbetreiber'].unique()
# Out:
# array(['Regionetz GmbH (SNB911641710114)',
#        'Netze BW GmbH (SNB948311994307)',
#        '50Hertz Transmission GmbH (SNB982046657236)',
#        'Amprion GmbH (SNB976890256486)',
#        'Überlandwerk Leinetal GmbH (SNB910956210043)',
#        'TransnetBW GmbH (SNB984944755380)',
#        'LEW Verteilnetz GmbH (SNB911705062982)',
#        'TEN Thüringer Energienetze GmbH & Co. KG (SNB970821959712)',
#        'E.DIS Netz GmbH (SNB941690671609)',
#        'Pfalzwerke Netz AG (SNB961471621746)',
#        'Infrastrukturbetrieb der Stadt Arneburg (SNB971962135690)',
#        'Westnetz GmbH (SNB921897286493)',
#        'Aschaffenburger Versorgungs-GmbH (SNB911081401368)',
#        'BIGGE ENERGIE GmbH & Co. KG (SNB990174285078)',
#        'swa Netze GmbH (SNB958077102830)',
#        'Bayernwerk Netz GmbH (SNB940352624434)',
#        'Mitteldeutsche Netzgesellschaft Strom mbH (SNB916269213931)',
#        'Avacon Netz GmbH (SNB990362338043)',
#        'DB Energie GmbH (Bahnstromnetz 16,7 Hz) (SNB942182027607)',
#        'GSW Gemeinschaftsstadtwerke GmbH Kamen, Bönen, Bergkamen (SNB935600499711)',
#        'Stromnetz Berlin GmbH (SNB979269087643)',
#        '50Hertz Transmission GmbH (SNB982046657236); Stromnetz Berlin GmbH (SNB979269087643)',
#        'Energienetze Berlin GmbH (SNB917314328846)',
#        'Creos Deutschland GmbH (SNB940133714842)',
#        'Bielefelder Netz GmbH (SNB918516395612)',
#        'Stadtwerke Bochum Netz GmbH (SNB922607376381)',
#        'Schleswig-Holstein Netz GmbH (SNB990857029876)',
#        'Bonn-Netz GmbH (SNB927498960503)',
#        'Versorgungsbetriebe Bordesholm GmbH (SNB973519584647)',
#        'Braunschweiger Netz GmbH (SNB926644622999)',
#        'wesernetz Bremen GmbH (SNB942238573102)',
#        'wesernetz Bremerhaven GmbH (SNB985704986426)',
#        'e-netz Südhessen AG (SNB956958990736)',
#        'Stadtwerke Brunsbüttel GmbH (SNB951835062254)',
#        'InfraServ Gendorf Netze GmbH (SNB942732578894)',
#        'inetz GmbH (SNB916663914472)',
#        'SÜC Energie und H²O GmbH (SNB968862623211)',
#        'Elektroenergieversorgung Cottbus GmbH (SNB931431136771)',
#        'EWE NETZ GmbH (SNB951051725711)',
#        'Amprion GmbH (SNB976890256486); DB Energie GmbH (Bahnstromnetz 16,7 Hz) (SNB942182027607)',
#        'Stadtwerke Delitzsch GmbH (SNB937001443546)',
#        'Dessauer Stromversorgung GmbH (SNB954281375657)',
#        'Energie Waldeck-Frankenberg GmbH (SNB936172924014)',
#        'N-ERGIE Netz GmbH (SNB973875583315)',
#        'Amprion GmbH (SNB976890256486); VSE Verteilnetz GmbH (SNB941650885558)',
#        'Dortmunder Netz GmbH (SNB981060961299)',
#        'Überlandwerk Eppler GmbH (SNB972264483465)',
#        'SachsenNetze HS.HD GmbH (SNB968914838013)',
#        'SachsenNetze GmbH (SNB980808485264)',
#        'Netze Duisburg GmbH (SNB916123648602)',
#        'Netzgesellschaft Düsseldorf mbH (SNB933956506145)',
#        'TenneT TSO GmbH (SNB970033313272)',
#        'Karlsruher Institut für Technologie (SNB955784827612)',
#        'SWE Netz GmbH (Erfurt) (SNB950262883869)',
#        'Erlanger Stadtwerke AG (SNB967982606159)',
#        'Mainsite GmbH & Co. KG (SNB974647435931)',
#        'badenovaNETZE GmbH (SNB965774651691)',
#        'SWM Infrastruktur GmbH & Co. KG (SNB969473762610)',
#        'ENERVIE Vernetzt GmbH (SNB921319639913)',
#        'Stadtwerke Flensburg GmbH (SNB922220582657)',
#        'Syna GmbH (SNB918250928893)',
#        'NRM Netzdienste Rhein-Main GmbH (SNB921899277833)',
#        'Amprion GmbH (SNB976890256486); Infraserv Netze GmbH (SNB977535807001)',
#        'Syna GmbH (SNB918250928893); Infraserv Netze GmbH (SNB977535807001)',
#        'Infraserv Netze GmbH (SNB977535807001)',
#        'Netzgesellschaft Frankfurt (Oder) mbH (SNB954814647626)',
#        'OsthessenNetz GmbH (SNB934071779865)',
#        'Hamburger Energienetze GmbH (SNB968295079586)',
#        'Albwerk GmbH & Co. KG (SNB926699071292)',
#        'GeraNetz GmbH (SNB948816192529)',
#        'Energieversorgung Filstal GmbH & Co. KG (SNB910995561328)',
#        'EAM Netz GmbH (SNB971311555230)',
#        'Stadtwerke Greifswald GmbH (SNB926442995943)',
#        'naturenergie netze GmbH (SNB945502201350)',
#        'Netzgesellschaft Gütersloh mbH (SNB931546188436)',
#        'Energieversorgung Halle Netz GmbH (SNB982934611074)',
#        'Westfalen Weser Netz GmbH (SNB929881052512)',
#        'Energie- und Wasserversorgung Hamm GmbH (SNB912743424114)',
#        'enercity Netz GmbH (SNB971746988153)',
#        'naturenergie netze GmbH (SNB945502201350); Netze BW GmbH (SNB948311994307)',
#        'Stadtwerke Heidelberg Netze GmbH (SNB938476571321)',
#        'Hellenstein-Energie-Logistik GmbH (SNB924453035597)',
#        'Hertener Stadtwerke GmbH (SNB964592501355)',
#        'Harz Energie Netz GmbH (SNB984607096621)',
#        'YNCORIS GmbH & Co. KG (SNB948485211972)',
#        'SWTE Netz GmbH & Co. KG (SNB950006175489)',
#        'Rheinhessische Energie- und Wasserversorgungs-GmbH (SNB912239808732)',
#        'Stadtwerke Ingolstadt Netze GmbH (SNB911347846643)',
#        'Stadtwerke Iserlohn GmbH (SNB913730249284)',
#        'Stadtwerke Jülich GmbH (SNB973672371320)',
#        'SWK Stadtwerke Kaiserslautern Versorgungs-AG (SNB982394830312)',
#        'Stadtwerke Karlsruhe Netzservice GmbH (SNB971087047229)',
#        'Städtische Werke Netz+Service GmbH (SNB935482852901)',
#        'Überlandwerk Mittelbaden GmbH & Co. KG (SNB913992545742)',
#        'STADTWERKE KELHEIM GmbH & Co KG (SNB965500640463)',
#        'Stadtwerke Kempen GmbH (SNB943042904373)',
#        'SWKiel Netz GmbH (SNB973742186519)',
#        'Energienetze Mittelrhein GmbH & Co. KG (SNB980055629275)',
#        'RheinNetz GmbH (SNB924477581384)',
#        'NETCUR GmbH (SNB974711150357)',
#        'Amprion GmbH (SNB976890256486); RheinNetz GmbH (SNB924477581384)',
#        'NGN Netzgesellschaft Niederrhein mbH (SNB911144461377)',
#        'Stadtwerke Landshut (SNB928992067729)',
#        'Stadtwerke Langen GmbH (SNB965379905076)',
#        'Stadtwerke Lemgo GmbH (SNB967075358620)',
#        'InfraLeuna GmbH (SNB982722829230)',
#        'WEMAG Netz GmbH (SNB928759560869)',
#        'Stadtwerke Ludwigsburg - Kornwestheim GmbH (SNB978730380269)',
#        'TWL Netze GmbH (SNB935578300972)',
#        'Stadtwerke Lünen GmbH (SNB942111583372)',
#        'Netze Magdeburg GmbH (SNB933459598975)',
#        'Mainzer Netze GmbH (SNB959523885956)',
#        'MVV Netze GmbH (SNB985472799266)',
#        'Amprion GmbH (SNB976890256486); MVV Netze GmbH (SNB985472799266); Pfalzwerke Netz AG (SNB961471621746); TransnetBW GmbH (SNB984944755380)',
#        'CPM Netz GmbH (SNB956923775696)',
#        'Flughafen München GmbH (SNB919526009605)',
#        'Stadtnetze Münster GmbH (SNB980883363112)',
#        'Neubrandenburger Stadtwerke GmbH (SNB939624707241)',
#        'Stadtwerke Neumarkt i. d. OPf. Energie GmbH (SNB989365725226)',
#        'KEW Kommunale Energie- und Wasserversorgung AG (SNB943841101959); Creos Deutschland GmbH (SNB940133714842)',
#        'Stadtwerke Ulm/Neu-Ulm Netze GmbH (SNB934068635945)',
#        'Oberhausener Netzgesellschaft mbH (SNB992672107807)',
#        'OQ Services GmbH (SNB985069443664)',
#        'Stadtwerke Oberkirch GmbH (SNB963821222269)',
#        'Energienetze Offenbach GmbH (SNB915100694458)',
#        'SWO Netz GmbH (SNB943662886851)',
#        'Vereinigte Wertach Elektrizitätswerke GmbH (SNB966808200267)',
#        'SWP Stadtwerke Pforzheim GmbH & Co. KG (SNB929168402344)',
#        'Netzgesellschaft Potsdam GmbH (SNB929027950139)',
#        'FairNetz GmbH (SNB991882909515)',
#        'Solvay Chemicals GmbH (SNB994887596117)',
#        'Stadtwerke Rosenheim Netze GmbH (SNB988838479086)',
#        'Stadtwerke Rostock Netzgesellschaft mbH (SNB939724292715)',
#        'EnR Energienetze Rudolstadt GmbH (SNB953495670831)',
#        'Stadtwerke Saarbrücken Netz AG (SNB985382489820)',
#        'VSE Verteilnetz GmbH (SNB941650885558)',
#        'LSW Netz GmbH & Co. KG (SNB957862279702)',
#        'BASF Schwarzheide GmbH (SNB911159111601)',
#        'Stadtwerke Schweinfurt GmbH (SNB922811950100)',
#        'Netzgesellschaft Schwerin mbH (NGS) (SNB913130054136)',
#        'SSW Netz GmbH (SNB989025785690)',
#        'Stadtwerke - Altm. Gas-, Wasseru.Elektrizitätswerke GmbH Stendal (SNB957404386462)',
#        'Stuttgart Netze GmbH (SNB947592865054)',
#        'AllgäuNetz GmbH & Co. KG (SNB926394308747)',
#        'Stadtwerke Torgau GmbH (SNB933235634552)',
#        'Stadtwerke Tübingen GmbH (SNB921695080347)',
#        'Stadtwerke Uelzen GmbH (SNB965557517831)',
#        'Netzbetreiber für im Ausland angeschlossene Anlagen (SNB995030145329)',
#        'Alzchem Netz GmbH (SNB922722422505)',
#        'Amprion GmbH (SNB976890256486); Westnetz GmbH (SNB921897286493)',
#        'Stadtwerke Wiesbaden Netz GmbH (SNB950584553167)',
#        'InfraServ GmbH & Co. Wiesbaden KG (SNB960884494671)',
#        'Stadtwerke Witzenhausen GmbH (SNB937722627607)',
#        'VW KRAFTWERK Gesellschaft mit beschränkter Haftung (SNB978865527096)',
#        'EWR Netz GmbH (SNB969068596941)',
#        'SWW Wunsiedel GmbH (SNB967812386411)',
#        'WSW Netz GmbH (SNB914306944756)',
#        'Mainfranken Netze GmbH (SNB915316807789)',
#        'Stadtwerke Suhl/Zella-Mehlis Netz GmbH (SNB935760057516)', nan],
#       dtype=object)

# %%
kws_cols.columns
# Out:
# Index(['MaStR-Nr. der Stromerzeugungseinheit', 'Anlagenbetreiber',
#        'Anzeige-Name der Stromerzeugungseinheit', 'PLZ der Einheit',
#        'Ort der Einheit', 'Straße der Einheit', 'Hausnummer der Einheit',
#        'Bundesland der Einheit',
#        'Datum der erstmaligen Inbetriebnahme der Einheit',
#        'Jahr der Inbetriebnahme der Einheit', 'Kraftwerksstatus der Einheit',
#        'Energieträger', 'Hauptbrennstoff', 'Speichertechnologie',
#        'Auswertung Energieträger', 'Wärmeauskopplung (KWK)\n(ja/nein)',
#        'Ist die Stromerzeugungseinheit ein Bestandteil eines Grenzkraftwerkes?',
#        'Bruttoleistung in MW',
#        'Nettonennleistung (elektrische Wirkleistung) in MW',
#        'Ist die Stromerzeugungseinheit ein Bestandteil eines Grenzkraftwerkes?: ja \nNettonennleistung der Einspeisung in ein deutsches Netz:',
#        'Technologie der Stromerzeugung',
#        'Volleinspeisung oder Teileinspeisung?', 'Anschlussnetzbetreiber',
#        'Spannungsebene'],
#       dtype='object')

# %%
net_solar = kw_solar.Net_Wirkleistung.sum()
net_wind = kw_wind.Net_Wirkleistung.sum()

print(f"Windeinspeisung: {net_wind} MWh; Solareinspeisung: {net_solar} MWh")
# Out:
# Windeinspeisung: 72804.1 MWh; Solareinspeisung: 89482.94 MWh

# %%
# Wetterdaten
import csv
wind_bam = pd.read_csv(wind_path, delimiter=';').rename(columns={
        'STATIONS_ID': 'id',
        'MESS_DATUM': 'timestamp',
        'QN_3': 'quality_lvl',
        '   F': 'speed',
        '   D': 'direction'
    }).drop(columns=['eor'])
wind_bam.timestamp = pd.to_datetime(wind_bam.timestamp, format='%Y%m%d%H')
wind_bam = wind_bam[wind_bam.timestamp.dt.year >= 2000]
wind_bam.set_index('timestamp')

wind_bam2 = pd.read_csv(wind_path2, delimiter=';').rename(columns={
    'STATIONS_ID': 'id',
    'MESS_DATUM': 'timestamp',
    'QN_8': 'quality_lvl',
    '  FF': 'speed',
    '  DD': 'direction'
}).drop(columns=['eor'])
wind_bam2.timestamp = pd.to_datetime(wind_bam2.timestamp, format='%Y%m%d%H')
wind_bam2 = wind_bam2[wind_bam2.timestamp.dt.year >= 2000]
wind_bam2.set_index('timestamp')
# Out:
#                       id  quality_lvl  speed  direction
# timestamp
# 2000-01-01 00:00:00  282            1    2.0        130
# 2000-01-01 01:00:00  282            1    2.0        150
# 2000-01-01 02:00:00  282            1    3.0        140
# 2000-01-01 03:00:00  282            1    2.0        160
# 2000-01-01 04:00:00  282            1    3.0        160
# ...                  ...          ...    ...        ...
# 2024-12-31 19:00:00  282            3    1.5        150
# 2024-12-31 20:00:00  282            3    4.1        150
# 2024-12-31 21:00:00  282            3    2.1        160
# 2024-12-31 22:00:00  282            3    2.4        150
# 2024-12-31 23:00:00  282            3    0.8        140
#
# [219125 rows x 4 columns]

# %%
wind_bam[wind_bam.speed == wind_bam.speed.max()]
# Out:
#          id           timestamp  quality_lvl  speed  direction
# 381752  282 2015-03-31 11:00:00           10   11.7        270

# %%
wind_bam2[(wind_bam2.speed == wind_bam2.speed.max()) & (wind_bam2.quality_lvl > 0)]
# Out:
#          id           timestamp  quality_lvl  speed  direction
# 193647  282 2000-01-20 17:00:00            1   21.0          0

# %%
wind_bam2[(wind_bam2.quality_lvl > 2) & (wind_bam2.speed > 10)]
# Out:
#          id           timestamp  quality_lvl  speed  direction
# 242034  282 2005-07-29 20:00:00            3   10.8        210
# 250742  282 2006-07-27 16:00:00            3   10.3        160
# 254945  282 2007-01-18 19:00:00            3   11.5        240
# 254950  282 2007-01-19 00:00:00            3   10.8        290
# 254951  282 2007-01-19 01:00:00            3   11.3        290
# 264714  282 2008-03-01 15:00:00            3   11.4        280
# 264734  282 2008-03-02 11:00:00            3   10.4        270
# 273015  282 2009-02-10 12:00:00            3   11.4        220
# 282210  282 2010-02-28 15:00:00            3   10.7        250
# 282211  282 2010-02-28 16:00:00            3   11.1        230
# 282834  282 2010-03-26 15:00:00            3   13.7        270
# 285480  282 2010-07-14 21:00:00            3   10.1        280
# 288386  282 2010-11-12 23:00:00            3   10.5        250
# 289277  282 2010-12-20 02:00:00            3   10.4        240
# 291998  282 2011-04-12 11:00:00            3   10.5        300
# 297957  282 2011-12-16 18:00:00            3   10.5        260
# 298430  282 2012-01-05 11:00:00            3   11.8        250
# 300498  282 2012-03-31 15:00:00            3   10.9        340
# 315242  282 2013-12-05 23:00:00            3   11.9        320
# 326738  282 2015-03-29 23:00:00            3   11.9        300
# 326751  282 2015-03-30 12:00:00            3   10.6        290
# 326754  282 2015-03-30 15:00:00            3   11.9        290
# 326755  282 2015-03-30 16:00:00            3   12.2        300
# 326770  282 2015-03-31 07:00:00            3   10.4        240
# 326771  282 2015-03-31 08:00:00            3   11.3        260
# 326772  282 2015-03-31 09:00:00            3   10.3        270
# 326774  282 2015-03-31 11:00:00            3   13.0        270
# 326776  282 2015-03-31 13:00:00            3   10.3        290
# 326777  282 2015-03-31 14:00:00            3   10.9        270
# 326778  282 2015-03-31 15:00:00            3   12.6        290
# 329561  282 2015-07-25 14:00:00            3   10.4        240
# 342465  282 2017-01-13 06:00:00            3   10.3        230
# 356227  282 2018-08-09 16:00:00            3   12.8        260
# 361189  282 2019-03-04 10:00:00            3   11.7        210
# 361190  282 2019-03-04 11:00:00            3   10.2        250
# 361192  282 2019-03-04 13:00:00            3   11.9        240
# 361319  282 2019-03-09 20:00:00            3   10.7        290
# 361338  282 2019-03-10 15:00:00            3   10.2        260
# 361341  282 2019-03-10 18:00:00            3   12.4        260
# 361342  282 2019-03-10 19:00:00            3   10.5        270
# 361343  282 2019-03-10 20:00:00            3   11.5        290
# 369413  282 2020-02-10 02:00:00            3   10.5        220
# 369415  282 2020-02-10 04:00:00            3   10.9        230
# 369421  282 2020-02-10 10:00:00            3   10.3        260
# 369422  282 2020-02-10 11:00:00            3   10.6        270
# 369423  282 2020-02-10 12:00:00            3   10.4        270
# 408242  282 2024-07-15 23:00:00            3   10.4        260

# %%
max_speed
# Out:
#          id           timestamp  quality_lvl  speed  direction
# 273121  282 2002-10-27 22:00:00           10   10.4        260
# 310086  282 2007-01-18 16:00:00           10   10.3        250
# 310090  282 2007-01-18 20:00:00           10   10.3        250
# 310093  282 2007-01-18 23:00:00           10   10.3        290
# 319832  282 2008-03-01 15:00:00           10   10.2        280
# 337330  282 2010-02-28 17:00:00           10   10.3        240
# 337952  282 2010-03-26 15:00:00           10   10.5        240
# 353424  282 2012-01-05 11:00:00           10   10.4        240
# 381749  282 2015-03-31 08:00:00           10   10.4        250
# 381750  282 2015-03-31 09:00:00           10   10.8        260
# 381751  282 2015-03-31 10:00:00           10   10.5        270
# 381752  282 2015-03-31 11:00:00           10   11.7        270
# 381753  282 2015-03-31 12:00:00           10   10.6        280
# 381755  282 2015-03-31 14:00:00           10   10.3        280
# 381756  282 2015-03-31 15:00:00           10   11.1        280
# 384528  282 2015-07-25 15:00:00           10   10.3        270
# 387304  282 2015-11-18 07:00:00           10   10.1        280
# 397430  282 2017-01-13 05:00:00           10   10.4        230
# 397431  282 2017-01-13 06:00:00           10   10.9        240
# 415961  282 2019-03-04 11:00:00           10   10.4        230
# 415962  282 2019-03-04 12:00:00           10   10.9        240
# 415963  282 2019-03-04 13:00:00           10   10.5        240
# 416112  282 2019-03-10 18:00:00           10   11.3        260
# 416113  282 2019-03-10 19:00:00           10   10.8        270
# 416114  282 2019-03-10 20:00:00           10   11.5        280

# %%
# Emissions data electricitymaps
df_emissions = pd.read_csv(ele_em)

# %%
df_emissions.head()
# Out:
#         Datetime (UTC)  Country Zone name Zone id  \
# 0  2024-01-01 00:00:00  Germany   Germany      DE
# 1  2024-01-01 01:00:00  Germany   Germany      DE
# 2  2024-01-01 02:00:00  Germany   Germany      DE
# 3  2024-01-01 03:00:00  Germany   Germany      DE
# 4  2024-01-01 04:00:00  Germany   Germany      DE
#
#    Carbon intensity gCO₂eq/kWh (direct)  \
# 0                                134.25
# 1                                135.33
# 2                                139.14
# 3                                140.23
# 4                                140.56
#
#    Carbon intensity gCO₂eq/kWh (Life cycle)  \
# 0                                    178.76
# 1                                    180.12
# 2                                    184.74
# 3                                    186.02
# 4                                    186.58
#
#    Carbon-free energy percentage (CFE%)  Renewable energy percentage (RE%)  \
# 0                                 82.96                              81.23
# 1                                 82.81                              81.47
# 2                                 82.32                              81.29
# 3                                 82.22                              81.48
# 4                                 82.16                              81.62
#
#   Data source  Data estimated  Data estimation method
# 0   entsoe.eu           False                     NaN
# 1   entsoe.eu           False                     NaN
# 2   entsoe.eu           False                     NaN
# 3   entsoe.eu           False                     NaN
# 4   entsoe.eu           False                     NaN

# %%
df_emissions['Carbon intensity gCO₂eq/kWh (direct)'].min()
# Out:
# 66.85
