# %%
import pandas as pd

from marginal_emissions.utils.helper import check_encoding

# %%
kws_path = '../data/raw/bundesnetzagentur/kraftwerksliste.csv'

encoding = check_encoding(path=kws_path)

if encoding:
    kws = pd.read_csv(kws_path, sep=';', skiprows=11, header=0, encoding=encoding, usecols=[
        'Anzeige-Name der Stromerzeugungseinheit',
        'Bundesland der Einheit',
        'Ort der Einheit',
        'Kraftwerksstatus der Einheit',
        'Energieträger',
        'Nettonennleistung (elektrische Wirkleistung) in MW',
        'Technologie der Stromerzeugung',
        'Spannungsebene'
    ]).rename(columns={
        'Anzeige-Name der Stromerzeugungseinheit': 'Name',
        'Bundesland der Einheit': 'Bundesland',
        'Ort der Einheit': 'Ort',
        'Kraftwerksstatus der Einheit': 'Status',
        'Nettonennleistung (elektrische Wirkleistung) in MW': 'Net_Wirkleistung',
        'Technologie der Stromerzeugung': 'Technologie'
    })
# Out:
# [INFO][2025-11-11 17:19:49,898][helper.py]_File is encoded as "Windows-1252"

# %%
    print(kws.head)
# Out:
# <bound method NDFrame.head of                                        Name          Ort           Bundesland  \
# 0                        BHKW Schwarzer Weg       Aachen  Nordrhein-Westfalen
# 1                                 HKW Aalen        Aalen    Baden-Württemberg
# 2     Gasturbinenkraftwerk Ahrensfelde GT A  Ahrensfelde          Brandenburg
# 3     Gasturbinenkraftwerk Ahrensfelde GT B  Ahrensfelde          Brandenburg
# 4     Gasturbinenkraftwerk Ahrensfelde GT C  Ahrensfelde          Brandenburg
# ...                                     ...          ...                  ...
# 2215                                    NaN          NaN             Saarland
# 2216                                    NaN          NaN              Sachsen
# 2217                                    NaN          NaN       Sachsen-Anhalt
# 2218                                    NaN          NaN   Schleswig-Holstein
# 2219                                    NaN          NaN            Thüringen
#
#                                          Status Energieträger  \
# 0                                    In Betrieb        Erdgas
# 1                                    In Betrieb        Erdgas
# 2     Kapazitätsreserve aufgrund von § 13e EnWG        Erdgas
# 3     Kapazitätsreserve aufgrund von § 13e EnWG        Erdgas
# 4     Kapazitätsreserve aufgrund von § 13e EnWG        Erdgas
# ...                                         ...           ...
# 2215                                 in Betrieb   Klärschlamm
# 2216                                 in Betrieb   Klärschlamm
# 2217                                 in Betrieb   Klärschlamm
# 2218                                 in Betrieb   Klärschlamm
# 2219                                 in Betrieb   Klärschlamm
#
#      Net_Wirkleistung                                    Technologie  \
# 0               21,51                              Verbrennungsmotor
# 1               78,30  Gasturbinen mit nachgeschalteter Dampfturbine
# 2               37,10                  Gasturbinen mit Abhitzekessel
# 3               37,10                  Gasturbinen mit Abhitzekessel
# 4               37,10                  Gasturbinen mit Abhitzekessel
# ...               ...                                            ...
# 2215             0,00                                            NaN
# 2216             0,77                                            NaN
# 2217             2,25                                            NaN
# 2218             0,95                                            NaN
# 2219             0,10                                            NaN
#
#                   Spannungsebene
# 0                 Mittelspannung
# 1     Hochspannung; Hochspannung
# 2                   Hochspannung
# 3                   Hochspannung
# 4                   Hochspannung
# ...                          ...
# 2215                         NaN
# 2216                         NaN
# 2217                         NaN
# 2218                         NaN
# 2219                         NaN
#
# [2220 rows x 8 columns]>

# %%
    kw_wasser = kws[kws['Technologie'].str.contains('wasser', case=False, na=False)]
    print(kw_wasser['Technologie'].unique())
# Out:
# []
