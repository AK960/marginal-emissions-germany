# %%
import pandas as pd

# %%
# Read dataframes
emissions = pd.read_csv('../data/interim/emissions_germany_202301010000_202501010000.csv',
    sep=',', index_col=0
)
f_hertz = pd.read_csv('../data/interim/generation_f_hertz_202301010000_202412312345.csv',
    sep=',', index_col=0
)
amprion = pd.read_csv('../data/interim/generation_amprion_202301010000_202412312345.csv',
    sep=',', index_col=0
)
tennet = pd.read_csv('../data/interim/generation_tennet_202301010000_202412312345.csv',
    sep=',', index_col=0
)
transnet_bw = pd.read_csv('../data/interim/generation_transnet_bw_202301010000_202412312345.csv',
    sep=',', index_col=0
)

# %%
"""
The generation timeseries consists of intervals such that the interval of time t contains [t, t+15)
The emissions timeseries consists of single points in time where at time t contains [t-60, t)
To align both, move emissions time series -1h such that t contains [t, t+60)
By forward filling, both time series can be aligned, such that for emissions also t contains [t, t+15)
--> Afterwards we can compute the hourly emissions per control area, weighed by their share of conventional generation
--> Next, we can perform a generation weighed downsampling of emissions to quarter hourly resolution
"""
# Align timeseries to period-start
